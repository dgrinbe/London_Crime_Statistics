# %%
#found more data:https://researchbriefings.files.parliament.uk/documents/CBP-7654/CBP-7654_download_july_2022.xlsx

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# %%
import pandas as pd

# %%
#Firearm data
#https://www.ons.gov.uk/peoplepopulationandcommunity/crimeandjustice/datasets/policeforceareadatatables
f_year=[x for x in range(2009,2022)]
f_england_and_wales=[8082,7040,6022,5158,4856,4911,5182,6375,6530,6882,6618,5715,5752]
f_england=[7927,6888,5903,5064,4756,4810,5068,6268,6428,6767,6491,5606,5625]
f_wales= [155,152,119,94,100,101,114,107,102,115,127,109,127]
f_north_east=[83,112,78,68,68,80,100,147,145,191,264,271,347]
f_north_west=[1272,1031,828,765,805,802,815,859,990,909,863,727,984]
f_yorkshire_and_humber=[454,427,410,478,448,425,592,786,727,816,742,769,723]
f_east_midlands=[398,387,357,307,245,244,324,401,399,484,566,459,472]
f_west_midlands=[1084,1095,794,628,677,662,663,754,862,1011,904,897,776]
f_east_england=[397,392,301,242,306,386,379,566,535,520,512,499,472]
f_london=[3524,2748,2482,1961,1596,1654,1556,2136,2127,2048,1767,1281,1071]
f_south_east=[445,401,309,369,358,290,361,367,350,463,580,402,508]
f_south_west=[270,295,344,246,253,267,278,252,293,325,293,301,272]

# %%
fig,ax=plt.subplots(3,1,figsize=(16,30))
ax[0].plot(f_year,f_england_and_wales,label='England and Wales')
ax[0].plot(f_year,f_england,label='England')
ax[0].plot(f_year,f_wales,label='Wales')
ax[0].plot(f_year,f_london,label='London')


ax[1].plot(f_year,f_wales,label='Wales')
ax[1].plot(f_year,f_north_east,label='North East')
ax[1].plot(f_year,f_north_west,label='North West')
ax[1].plot(f_year,f_yorkshire_and_humber,label='Yorkshire and Humber')
ax[1].plot(f_year,f_east_midlands,label='East Midlands')
ax[1].plot(f_year,f_west_midlands,label='West Midlands')
ax[1].plot(f_year,f_east_england,label='East England')
ax[1].plot(f_year,f_london,label='London')
ax[1].plot(f_year,f_south_east,label='South East')
ax[1].plot(f_year,f_south_west,label='South West')

ax[2].plot(f_year,f_wales,label='Wales')
ax[2].plot(f_year,f_north_east,label='North East')
ax[2].plot(f_year,f_north_west,label='North West')
ax[2].plot(f_year,f_yorkshire_and_humber,label='Yorkshire and Humber')
ax[2].plot(f_year,f_east_midlands,label='East Midlands')
ax[2].plot(f_year,f_west_midlands,label='West Midlands')
ax[2].plot(f_year,f_east_england,label='East England')
ax[2].plot(f_year,f_south_east,label='South East')
ax[2].plot(f_year,f_south_west,label='South West')


ax[0].legend(loc='upper right')
ax[1].legend(loc='best',ncol=2)
ax[2].legend(loc='best',ncol=2)

ax[0].set_title(label='Firearm offences (excluding air weapons), year ending March 2010 to year ending March 2022')
ax[1].set_title(label='Firearm offences (excluding air weapons), by police district')
ax[2].set_title(label='Firearm offences (excluding air weapons), by police district (excluding london)')

plt.show()

# %%
df_offense_group=pd.read_csv("firearm offences by offence group.csv")
df_offense_group.set_index('Type of Firearm', inplace=True)
df_offense_group
# Out:
#                                         Category  2010/11  2011/12  2012/13  \
# Type of Firearm
# Non-air firearms     Violence against the person     2266     1937     1592
# Non-air firearms                         Robbery     2925     2533     2172
# Non-air firearms                        Burglary      147      139       97
# Non-air firearms                 Criminal damage      374      333      335
# Non-air firearms  Public fear, alarm or distress      261      203      200
# Non-air firearms           Possession of weapons      852      695      603
# Non-air firearms          Other firearm offences      215      182      159
# Air weapons          Violence against the person      556      429      425
# Air weapons                              Robbery       50       34       34
# Air weapons                             Burglary        8       12        5
# Air weapons                      Criminal damage     3197     2669     2091
# ...

# %%
(df_offense_group.iloc[:7].sum().to_list())
# Out:
# ['Violence against the personRobberyBurglaryCriminal damagePublic fear, alarm or distressPossession of weaponsOther firearm offences',
#  7040,
#  6022,
#  5158,
#  4856,
#  4911,
#  5182,
#  6375,
#  6534,
#  6884,
#  6622,
#  5709]

# %%
df_offense_group[df_offense_group.columns.to_list()[1:]].pct_change()
# Out:
#                      2010/11     2011/12     2012/13      2013/14     2014/15  \
# Type of Firearm
# Non-air firearms         NaN         NaN         NaN          NaN         NaN
# Non-air firearms    0.290821    0.307692    0.364322     0.334473    0.097403
# Non-air firearms   -0.949744   -0.945124   -0.955341    -0.942594   -0.936095
# Non-air firearms    1.544218    1.395683    2.453608     1.946429    1.962963
# Non-air firearms   -0.302139   -0.390390   -0.402985    -0.318182   -0.009375
# Non-air firearms    2.264368    2.423645    2.015000     1.777778    1.309148
# Non-air firearms   -0.747653   -0.738129   -0.736318    -0.758400   -0.721311
# Air weapons         1.586047    1.357143    1.672956     1.649007    0.803922
# Air weapons        -0.910072   -0.920746   -0.920000    -0.935000   -0.932065
# Air weapons        -0.840000   -0.647059   -0.852941    -0.923077   -0.840000
# Air weapons       398.625000  221.416667  417.200000  1053.500000  547.250000
# ...

# %%
df_offense_group.iloc[[i,(i+7)]].sum()[1:].pct_change().to_list()
# Out:
# [nan,
#  -0.1615875265768958,
#  -0.14750633981403216,
#  -0.07684680218145756,
#  0.02470461868958118,
#  0.1850104821802936,
#  0.15833701901813346,
#  -0.021000381825124093,
#  0.10686427457098291,
#  -0.009161381254404466,
#  -0.05903271692745382]

# %%
fig,ax=plt.subplots(4,2,figsize=(20,30))


#line charts

#df_offense_group.iloc[1][1:].pct_change()
for i in range(7):
    ax[0,0].plot(df_offense_group.columns.to_list()[1:],df_offense_group.iloc[i][1:].to_list(),label=df_offense_group.iloc[i][0])
    ax[1,0].plot(df_offense_group.columns.to_list()[1:],df_offense_group.iloc[(i+7)][1:].to_list(),label=df_offense_group.iloc[(i+7)][0])
    
for i in range(7):
    ax[2,0].plot(df_offense_group.columns.to_list()[1:],(df_offense_group.iloc[[i,(i+7)]].sum()).to_list()[1:],label=df_offense_group.iloc[i][0])

    
ax[3,0].plot(df_offense_group.columns.to_list()[1:],df_offense_group.iloc[:7].sum()[1:],label='Non-Air Firearms')
ax[3,0].plot(df_offense_group.columns.to_list()[1:],df_offense_group.iloc[7:].sum()[1:],label='Air Weapons')




ax[0,0].set_title("Non-Air Firearms")
ax[1,0].set_title("Air Weapons")
ax[2,0].set_title("By category")
ax[3,0].set_title("Combined")
    
ax[0,0].legend(loc='best')
ax[1,0].legend(loc='best')
ax[2,0].legend(loc='best')
ax[3,0].legend(loc='best')

# ############ pct change


for i in range(7):
    ax[0,1].plot(df_offense_group.columns.to_list()[1:],df_offense_group.iloc[i][1:].pct_change().to_list(),label=df_offense_group.iloc[i][0])
    ax[1,1].plot(df_offense_group.columns.to_list()[1:],df_offense_group.iloc[(i+7)][1:].pct_change().to_list(),label=df_offense_group.iloc[(i+7)][0])
    
for i in range(7):
    ax[2,1].plot(df_offense_group.columns.to_list()[1:],df_offense_group.iloc[[i,(i+7)]].sum()[1:].pct_change().to_list(),label=df_offense_group.iloc[i][0])
    
ax[3,1].plot(df_offense_group.columns.to_list()[1:],df_offense_group.iloc[:7].sum()[1:].pct_change(),label='Non-Air Firearms')
ax[3,1].plot(df_offense_group.columns.to_list()[1:],df_offense_group.iloc[7:].sum()[1:].pct_change(),label='Air Weapons')

ax[0,1].set_title("Non-Air Firearms % change")
ax[1,1].set_title("Air Weapons % change")
ax[2,1].set_title("By category % change")
ax[3,1].set_title("Combined % change")
    
ax[0,1].legend(loc='best')
ax[1,1].legend(loc='best')
ax[2,1].legend(loc='best')
ax[3,1].legend(loc='best')


ax[0,1].set_yticks(list(np.linspace(-.4,1.4,num=10)))
for i in list(np.linspace(-.4,1.4,num=10)):
    ax[0,1].axhline(i,alpha=.2,color='black',linestyle='--')

ax[1,1].set_yticks(list(np.linspace(-1,4,num=11)))
for i in list(np.linspace(-1,4,num=11)):
    ax[1,1].axhline(i,alpha=.2,color='black',linestyle='--')


ax[2,1].set_yticks(list(np.linspace(-.5,1,num=11)))
for i in list(np.linspace(-.5,1,num=11)):
    ax[2,1].axhline(i,alpha=.2,color='black',linestyle='--')

ax[3,1].set_yticks(list(np.linspace(-.3,.3,num=13)))
for i in list(np.linspace(-.3,.3,num=13)):
    ax[3,1].axhline(i,alpha=.2,color='black',linestyle='--')
##########
ax[0,0].set_yticks(range(0,3250,250))
for i in range(0,3250,250):
    ax[0,0].axhline(i,alpha=.2,color='black',linestyle='--')

ax[1,0].set_yticks(range(0,3550,250))
for i in range(0,3550,250):
    ax[1,0].axhline(i,alpha=.2,color='black',linestyle='--')

ax[2,0].set_yticks(range(0,3550,250))
for i in range(0,3550,250):
    ax[2,0].axhline(i,alpha=.2,color='black',linestyle='--')
    
ax[3,0].set_yticks(range(0,8500,500))
for i in range(0,8500,500):
    ax[3,0].axhline(i,alpha=.2,color='black',linestyle='--')

######

plt.show()

# %%
df_offense_group.iloc[1][1:].to_list()
# Out:
# [2925, 2533, 2172, 1951, 1690, 1528, 1663, 1658, 1765, 1398, 941]

# %%
list(np.linspace(-.3,.3,num=30))
# Out:
# [-0.3,
#  -0.2793103448275862,
#  -0.2586206896551724,
#  -0.2379310344827586,
#  -0.21724137931034482,
#  -0.19655172413793104,
#  -0.17586206896551723,
#  -0.15517241379310343,
#  -0.13448275862068965,
#  -0.11379310344827587,
#  -0.09310344827586206,
#  -0.07241379310344825,
#  -0.051724137931034475,
#  -0.031034482758620696,
#  -0.010344827586206862,
#  0.010344827586206917,
#  0.031034482758620696,
#  0.051724137931034475,
#  0.07241379310344825,
#  0.09310344827586209,
#  0.11379310344827587,
#  0.13448275862068965,
#  0.15517241379310348,
#  0.17586206896551726,
#  0.19655172413793104,
#  0.21724137931034487,
#  0.2379310344827586,
#  0.25862068965517243,
#  0.27931034482758627,
#  0.3]

# %% [markdown]
# _____________

# %%
#table 12
as_year=[x for x in range(2007,2022)]
as_england_and_wales=[3873916,72,3673523,68,3532250,64,3217817,58,2722663,49,2258805,40,2065877,37,1941885,34,1791027,31,1794963,30,1633591,27,1421963,24,1348726,23,2024344,34,1267695,21]#excluding british transport police
as_england=[3602673,71,3422894,67,3290560,64,3004146,58,2558433,49,2139932,40,1951915,36,1831129,34,1692478,31,1698916,30,1542900,27,1351231,24,1283984,23,1914318,34,1204326,21]
as_north_east=[298864,117,271707,106,249744,97,228732,89,188860,73,157483,61,148541,57,149828,57,135385,52,125649,47,115497,43,100601,38,92256,34,132557,49,88231,33]
as_north_west=[639605,93,587949,85,536000,77,447585,64,382564,54,355837,50,324054,46,321992,45,308393,43,299268,41,236355,32,177913,24,182325,25,268957,37,167487,23]
as_yorkshire_and_humber=[379887,74,369038,71,363394,70,324008,62,262699,50,209575,40,198901,37,194790,36,184816,34,183639,33,163331,30,131870,24,114469,21,143389,26,97823,18]
as_east_midlands=[325129,74,313059,71,290227,65,261649,59,213769,47,173227,38,162171,36,159867,35,149548,32,147294,30,137041,28,124966,26,109827,23,161405,33,103351,21]
as_west_midlands=[353082,65,359175,66,330471,60,277066,50,214405,39,185254,33,172769,31,162705,29,155783,27,159028,27,155708,26,138952,23,118455,20,181741,30,103606,17]
as_east_england=[380322,68,363189,64,341982,60,302792,53,246351,42,201959,34,177029,30,179829,30,161411,27,166458,27,152258,24,129726,21,117703,19,144066,23,102474,16]
as_london=[389764,51,365764,48,421801,54,465106,59,467290,58,387812,47,344291,41,266496,32,245085,29,276281,31,250790,28,252469,28,278344,31,519311,58,292220,32]
as_south_east=[501524,61,467008,56,455723,54,421577,50,347664,41,279291,32,240419,28,226588,26,203237,23,195660,21,187842,20,159523,17,150294,16,211084,23,138725,15]
as_south_west=[334496,65,326005,63,301218,58,275631,53,234831,45,189494,36,183740,34,169034,31,148820,27,145639,26,144078,25,135211,24,120311,21,151808,27,110409,20]
as_wales=[271243,91,250629,83,241690,80,213671,70,164230,54,118873,39,113962,37,110756,36,98549,32,96047,30,90691,29,70732,22,64742,20,110026,35,63369,20]
as_places=[as_england_and_wales,as_england,as_wales,as_north_east,as_north_west,as_yorkshire_and_humber,as_east_midlands,as_west_midlands,as_east_england,as_london,as_south_east,as_south_west]

# %%
#remove the crimes per 1000 people
def cleanup(my_list):
    for i in my_list:
        if len(str(i))<4:
            my_list.remove(i)
    return my_list

# %%
cleanup(as_england_and_wales)
cleanup(as_england)
cleanup(as_wales)
cleanup(as_north_east)
cleanup(as_north_west)
cleanup(as_yorkshire_and_humber)
cleanup(as_east_midlands)
cleanup(as_west_midlands)
cleanup(as_east_england)
cleanup(as_london)
cleanup(as_south_east)
cleanup(as_south_west)
# Out:
# [334496,
#  326005,
#  301218,
#  275631,
#  234831,
#  189494,
#  183740,
#  169034,
#  148820,
#  145639,
#  144078,
#  135211,
#  120311,
#  151808,
#  110409]

# %%
[(f'{int(i)-1}-{i}') for i in as_year]
# Out:
# ['2006-2007',
#  '2007-2008',
#  '2008-2009',
#  '2009-2010',
#  '2010-2011',
#  '2011-2012',
#  '2012-2013',
#  '2013-2014',
#  '2014-2015',
#  '2015-2016',
#  '2016-2017',
#  '2017-2018',
#  '2018-2019',
#  '2019-2020',
#  '2020-2021']

# %%
fig,ax=plt.subplots(2,1,figsize=(16,20))
ax[0].plot(as_year,as_england_and_wales,label='England and Wales')
ax[0].plot(as_year,as_england,label='England')
ax[0].plot(as_year,as_wales,label='Wales')
#ax[0].plot(as_year,as_london,label='London')

ax[0].set_yticks(list(range(0,5_000_000,500_000)))

ax[0].ticklabel_format(axis='y',style='plain')
for i in range(0,5_000_000,500_000):
    ax[0].axhline(i,color='black',alpha=.2,linestyle='--')

#ax[0].set_xticks([(f'{int(i)-1}-{i}') for i in as_year])
ax[0].set_xticks(as_year)
ax[1].set_xticks(as_year)


ax[1].plot(as_year,as_wales,label='Wales')
ax[1].plot(as_year,as_north_east,label='North East')
ax[1].plot(as_year,as_north_west,label='North West')
ax[1].plot(as_year,as_yorkshire_and_humber,label='Yorkshire and Humber')
ax[1].plot(as_year,as_east_midlands,label='East Midlands')
ax[1].plot(as_year,as_west_midlands,label='West Midlands')
ax[1].plot(as_year,as_east_england,label='East England')
ax[1].plot(as_year,as_london,label='London')
ax[1].plot(as_year,as_south_east,label='South East')
ax[1].plot(as_year,as_south_west,label='South West')


ax[1].set_yticks(list(range(0,600_000,50_000)))
for i in range(0,600_000,50_000):
    ax[1].axhline(i,color='black',alpha=.2,linestyle='--')

ax[0].legend(loc='upper right')
ax[1].legend(loc='best',ncol=2)

#axis titles
ax[0].set_xlabel('Year')
ax[0].set_ylabel("Total number of incidents")
ax[1].set_xlabel('Year')
ax[1].set_ylabel("Total number of incidents")

ax[0].set_title(label='Anti-social behaviour incidents, year ending March 2008 to year ending March 2022')
ax[1].set_title(label='Anti-social behaviour incidents by police district, year ending March 2008 to year ending March 2022')

plt.show()
